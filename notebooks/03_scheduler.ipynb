# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(".."))

from src.config import load_config
from src.simulation import run, jains_fairness_index

# Carrega configurações e força execução do 'max_c_i' sem salvar arquivos no disco
cfg = load_config()
cfg.save_results = False

# Roda a simulação para o Max C/I em todas as cargas e seeds configuradas
results = run(cfg, schedulers=["max_c_i"])

per_ue_df = results["per_ue"]
per_seed_df = results["per_seed"]
summary_df = results["summary"]

print("Simulação concluída!")
display(summary_df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 10
#       6
#       7 sys.path.append(os.path.abspath(".."))
#       8
#       9 from src.config import load_config
# ---> 10 from src.simulation import run, jains_fairness_index
#      11
#      12 # Carrega configurações e força execução do 'max_c_i' sem salvar arquivos no disco
#      13 cfg = load_config()
#
# File ~\Documents\GitHub\5g-scheduler-load-analysis\src\simulation.py:38
#      36 from .channel import compute_rates, generate_channel
#      37 from .config import Config, load_config
# ---> 38 from src.schedulers import create_scheduler
#      41 # Scheduler vazio (card 1), embutido aqui para não invadir o escopo dos
#      42 # cards 2-4. Os schedulers reais virão em src/schedulers.py.
#      43 class EmptyScheduler:
#
# ...
